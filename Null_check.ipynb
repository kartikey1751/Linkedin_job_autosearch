# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import os
import warnings
warnings.filterwarnings("ignore")
import requests
from bs4 import BeautifulSoup

# %%
url_Jobs = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=&location=Worldwide&locationId=&geoId=92000000&f_TPR=&f_JT=F%2CC&f_WT=2"

# %%
locations = []
titles = []
countries = []    
links = []
company_name = []


for i in range(0,3,1):
    url = url_Jobs+"&start="+str(i)
    request = requests.get(url)
    data = request.text
    soup = BeautifulSoup(data)
    location = soup.findAll("span", {"class":"job-search-card__location"})
    for i in location:
        if i is not None:
            locations.append(i.text.replace("\n"," ").strip(" "))   
        else:
            locations.append("NA")
    title = soup.findAll("h3",{"class":"base-search-card__title"})
    for i in title:
        if i is not None:
            titles.append(i.text.replace("\n"," ").strip(" ")) 
        else:
            titles.append("NA")
    country = soup.findAll("span", {"class":"job-search-card__location"})
    for i in country:
        if i is not None:
            countries.append(i.text.replace("\n"," ").strip(" ").split(',')[-1])
        else:
            countries.append("NA")
    job_links = soup.findAll("a",{"class":"base-card__full-link"})
    for i in job_links:
        if i is not None:
            links.append(i["href"])
        else:
            links.append("NA")
    names = soup.findAll("a",{"class":"hidden-nested-link"})
    for i in names:
        if i is not None:
            company_name.append(i.text.replace("\n"," ").strip(" ")) 
        else:
            company_name.append("NA")
# Out:
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://br.linkedin.com/jobs/view/assistente-de-relacionamento-influenciadores-at-digital-influencers-brasil-3837116679?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=vdIgEUjGaG4G7ScRdN%2FZ9Q%3D%3D&amp;position=1&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Assistente de Relacionamento - Influenciadores
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://co.linkedin.com/jobs/view/auxiliar-administrativo-at-compensar-3837211784?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=EF2sUXwhO0I4Com%2F7LH%2BPQ%3D%3D&amp;position=2&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Auxiliar administrativo
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://co.linkedin.com/jobs/view/profesional-atenci%C3%B3n-comunitaria-vivienda-at-compensar-3837119560?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=SlgZsPEkKtm7HnTxx%2Ffgxg%3D%3D&amp;position=3&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         - Profesional Atención Comunitaria- Vivienda
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/creative-director-at-netflix-3837176528?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=j4Q%2FSU3yeuRhVNc8VBZcmQ%3D%3D&amp;position=4&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Creative Director
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/admin-assistant-remote-at-brighty-careers-3837281631?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=CN8J1TykMYQGAUeVClq5SQ%3D%3D&amp;position=5&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Admin Assistant - Remote
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/sales-development-representative-at-tremendous-3836982864?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=3YOQc%2FGFDlbs9dIeIX9qMQ%3D%3D&amp;position=6&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Sales Development Representative
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/scheduler-remote-entry-level-at-tropical-haven-voyage-3837409988?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=OsfXRB8d34BpW%2B%2Fhur%2FVkA%3D%3D&amp;position=7&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Scheduler/Remote (Entry Level)
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/online-chat-representative-remote-at-suryl-llc-3837149993?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=XVbqxvWmcfuMbWmh6wHocw%3D%3D&amp;position=8&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Online Chat Representative (Remote)
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/senior-healthcare-recruiter-at-amx-healthcare-3837216381?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=U1QypKYVeUAHvGXAePmElQ%3D%3D&amp;position=9&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Senior Healthcare Recruiter
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/payroll-clerk-at-sky-zone-3837151585?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=FINy4TXAjFmCl0rlr1EUIw%3D%3D&amp;position=10&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Payroll Clerk
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/director-of-learning-experience-at-wiz-3837147180?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=v%2FoGBN9lM7C6K8ONexr11w%3D%3D&amp;position=11&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Director of Learning Experience
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/call-center-supervisor-at-prudentrx-3837226278?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=tNjaEy37TCjkRpJyWAh66g%3D%3D&amp;position=12&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Call Center Supervisor
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/full-time-marketing-assistant-remote-at-shine-3837279832?refId=ZeTJrXaQeTP8vNWkoQD%2F6A%3D%3D&amp;trackingId=k%2Br%2F4tLnkVGjCVAM%2FdtLWw%3D%3D&amp;position=13&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         
amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Agente de Reservaciones
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/assistant-coordinator-remote-at-norton-consulting-3837694518?refId=ZnXh0%2BOPHfdhFs2OZgvcIw%3D%3D&amp;trackingId=1YiwhvGnL5522SPIxZPTrQ%3D%3D&amp;position=22&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Assistant Coordinator (Remote)
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/personal-assistant-remote-at-brighty-careers-3837277841?refId=ZnXh0%2BOPHfdhFs2OZgvcIw%3D%3D&amp;trackingId=H3vzY6kXlHV687YS968ZzQ%3D%3D&amp;position=23&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Personal Assistant - Remote
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/sporting-event-coordinator-remote-at-norton-consulting-3837224667?refId=ZnXh0%2BOPHfdhFs2OZgvcIw%3D%3D&amp;trackingId=qqkM0iFYmFWkv1ujSfCmRg%3D%3D&amp;position=24&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Sporting Event Coordinator (Remote)
#
#
#           </span>
# </a>
# <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-will-navigate="" href="https://www.linkedin.com/jobs/view/remote-medical-receptionist-at-careharmony-3837180029?refId=ZnXh0%2BOPHfdhFs2OZgvcIw%3D%3D&amp;trackingId=toNfucdA54hseQVZZC5u6g%3D%3D&amp;position=25&amp;pageNum=0&amp;trk=public_jobs_jserp-result_search-card">
# <span class="sr-only">
#
#
#         Remote - Medical Receptionist
#
#
#           </span>
# </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://mx.linkedin.com/company/radicalnetworks?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Radical Networks
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/netflix?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Netflix
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/brighty-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Brighty Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/tropical-haven-voyages?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Tropical Haven Voyage
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/amxhealthcare?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             AMX Healthcare
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/shine-shine-shine?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Shine
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/lumatahealth?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Lumata Health
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/weld-north-education?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Weld North Education (now Imagine Learning)
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/superus-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Superus Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/sparkplugapp?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             SparkPlug
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/brighty-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Brighty Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://br.linkedin.com/company/portusdigital?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Portus Digital
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/brighty-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Brighty Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/tropical-haven-voyages?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Tropical Haven Voyage
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/letsremotivate?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Remotivate
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/counciloncj?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Council on Criminal Justice
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/team-remotely-llc?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Team Remotely Inc
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/cerge?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Cerge
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/team-remotely-llc?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Team Remotely Inc
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/brighty-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Brighty Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/peninsula-publishing?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Peninsula Publishing
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/pat-norton-consulting?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Norton Consulting
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://uk.linkedin.com/company/brighty-careers?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Brighty Careers
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/pat-norton-consulting?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             Norton Consulting
#           </a>
# <a class="hidden-nested-link" data-tracking-client-ingraph="" data-tracking-control-name="public_jobs_jserp-result_job-search-card-subtitle" data-tracking-will-navigate="" href="https://www.linkedin.com/company/careharmony?trk=public_jobs_jserp-result_job-search-card-subtitle">
#             CareHarmony
#           </a>

# %%
print(len(locations))
print(len(titles))
print(len(countries))
print(len(links))
print(len(company_name))
# Out:
# 74
# 74
# 74
# 73
# 73

# %%
df1 = pd.DataFrame(titles,columns=["Title"])
df1["Location"] = locations
df1["Country"] = countries
df1["Links"] = links
df1["Company_Name"] = company_name

df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 df1["Location"] = locations
#       3 df1["Country"] = countries
# ----> 4 df1["Links"] = links
#       5 df1["Company_Name"] = company_name
#       7 df1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4296     self._setitem_array([key], value)
#    4297 else:
#    4298     # set column
# -> 4299     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4512, in DataFrame._set_item(self, key, value)
#    4502 def _set_item(self, key, value) -> None:
#    4503     """
#    4504     Add series to DataFrame in specified column.
#    4505
#    (...)
#    4510     ensure homogeneity.
#    4511     """
# -> 4512     value, refs = self._sanitize_column(value)
#    4514     if (
#    4515         key in self.columns
#    4516         and value.ndim == 1
#    4517         and not isinstance(value.dtype, ExtensionDtype)
#    4518     ):
#    4519         # broadcast across multiple columns if necessary
#    4520         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5253, in DataFrame._sanitize_column(self, value)
#    5250     return _reindex_for_setitem(value, self.index)
#    5252 if is_list_like(value):
# -> 5253     com.require_length_match(value, self.index)
#    5254 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5255 if (
#    5256     isinstance(value, Index)
#    5257     and value.dtype == "object"
#    (...)
#    5260     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5261     # this deprecation
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (73) does not match length of index (74)
